# %%
from openpyxl import load_workbook
import re
import numpy as np

file_path = "../input_file/OBP_counterparties_TESOBE_Hong_Kong.xlsx"
wb = load_workbook(file_path)

# %%
city = "Hong Kong"

sheet_selected = [sheetname for sheetname in wb.sheetnames if city in sheetname ]

# %%
import pandas as pd

dataframe = pd.read_excel(file_path, sheet_name = sheet_selected, header=None, index_col=None, skiprows=3)

for i, j in dataframe.items():
    df = pd.DataFrame(j)

df.columns= ['type', 'name', 'reference', 'value', 'frequency', 'logo','homepage']

frequecy_mapping = {
    "yearly" : 0.1/12,
    "monthly" : 1,
    "weekly" : 4,
    "fortnightly" : 2,
    "quarterly" : 4,
    "quartley":4
}

counterparty_frequency = {
    'airline':1.0/12,
    'airport services':1.0/12,
    'attraction':3.0/12,
    'bar':4,
    'booking.com':1.0/12,
    'car service':6.0/12,
    'charity':1.0/12,
    'cinema':1,
    'coffee':4,
    'comercial door suppilers':0,
    'council tax':1,
    'dental clinic':1.0/12,
    'estate agent':0,
    'filling station':2,
    'flights':1.0/12,
    'freight services':0,
    'groceries':4,
    'gym':1,
    'industiral process company':0,
    'industrial glass and machinery':0,
    'insurance':1,
    'it company':0,
    'manufacturing':0,
    'mobile':1,
    'monthly membership':1,
    'mortgage':1,
    'office suppliers':1,
    'opticitan':1.0/12,
    'parking':1,
    'pharmacy':1,
    'pipeline suppilers':0,
    'repair and maintenance':1.0/12,
    'repair and maintence':1.0/12,
    'repair':1.0/12,
    'restaurant':4,
    'road tax':1,
    'savings':1.0/12,
    'school':1.0/12,
    'shipping company':1,
    'shopping':1,
    'sky tv':1.0/12,
    'spa':1.0/12,
    'suppilers of cooler items':1.0/12,
    'suppliers of large electronic':1.0/12,
    'takeway':1.0/12,
    'telecom':1.0/12,
    'tickets':1.0/12,
    'trading':1.0/12,
    'travel':1.0/12,
    'utility':1.0/12,
    'yatch club':1.0/12,
    'atm':1.0/12,
    'donation':1.0/12,
    'income':1.0/12,
    'transfer':1.0/12,
    'business rates':1.0/12,
    'rent':1.0/12,
    'transfer salary':1.0/12,
    'salary':1.0/12,
    'business insurance':1.0/12,
    'credit card':1.0/12
}

# %%
df.type = df["type"].apply(lambda x: re.split('_|/',x)[0].lower())
df.frequency = df["frequency"].apply(lambda x: str("0") if x is np.nan else frequecy_mapping[x.lower()])

df = pd.DataFrame({
    "type":df["type"].apply(lambda x: re.split('_|/',x)[0].lower()),
    "name" : df["name"],
    "value" : df["value"],
    "frequency" : df["frequency"].apply(lambda x: str("0") if x is np.nan else frequecy_mapping[x.lower()]),
    "logo" : df["logo"],
    "homepage" : df["homepage"]
})

# %%
[i for i in df["type"].drop_duplicates()]
# Out:
# ['airline',
#  'airport services',
#  'attraction',
#  'bar',
#  'booking.com',
#  'car service',
#  'charity',
#  'cinema',
#  'coffee',
#  'comercial door suppilers',
#  'council tax',
#  'dental clinic',
#  'estate agent',
#  'filling station',
#  'flights',
#  'freight services',
#  'groceries',
#  'gym',
#  'industiral process company',
#  'industrial glass and machinery',
#  'insurance',
#  'it company',
#  'manufacturing',
#  'mobile',
#  'monthly membership',
#  'mortgage',
#  'office suppliers',
#  'opticitan',
#  'parking',
#  'pharmacy',
#  'pipeline suppilers',
#  'repair and maintenance',
#  'repair and maintence',
#  'repair',
#  'restaurant',
#  'road tax',
#  'savings',
#  'school',
#  'shipping company',
#  'shopping',
#  'sky tv',
#  'spa',
#  'suppilers of cooler items',
#  'suppliers of large electronic',
#  'takeway',
#  'telecom',
#  'tickets',
#  'trading',
#  'travel',
#  'utility',
#  'yatch club',
#  'atm',
#  'donation',
#  'income',
#  'transfer',
#  'business rates',
#  'rent',
#  'transfer salary',
#  'salary',
#  'business insurance',
#  'credit card']

# %%
country = "Mexico"
city = ""
# Out:
# 0               0
# 1               0
# 2      0.00833333
# 3      0.00833333
# 4               4
# 5               1
# 6      0.00833333
# 7               0
# 8               0
# 9               0
# 10              1
# 11              4
# 12              2
# 13              0
# 14              1
# 15     0.00833333
# 16              0
# 17              2
# 18              4
# 19     0.00833333
# 20              0
# 21              0
# 22              4
# 23              1
# 24              4
# 25              1
# 26              4
# 27              4
# 28              1
# 29              0
#           ...
# 127             0
# 128             0
# 129             0
# 130             0
# 131             0
# 132             0
# 133             0
# 134             0
# 135             0
# 136             0
# 137             0
# 138             0
# 139             0
# 140             0
# 141             0
# 142             0
# 143             0
# 144             0
# 145             0
# 146             0
# 147             0
# 148             0
# 149             0
# 150             0
# 151             0
# 152             0
# 153             1
# 154             0
# 155             0
# 156             0
# Name: frequency, Length: 157, dtype: object

# %%
from googleplaces import GooglePlaces
import googlemaps

import json
import sys

import importlib,sys
importlib.reload(sys)
# Out:
# <module 'sys' (built-in)>

# %%
class GoogleMaps(object):
    """提供google maps服务"""

    def __init__(self):

        self._GOOGLE_MAPS_KEY = "AIzaSyDonfkHvaaMdi5XhAdusk8ObfzCZe3aTJE"
        self._Google_Places = GooglePlaces(self._GOOGLE_MAPS_KEY)
        self._Google_Geocod = googlemaps.Client(key=self._GOOGLE_MAPS_KEY)

    def _text_search(self, query, language=None, location=None):
        """
        根据搜索字符串,请求google API传回推荐的列表
        :param query: 搜索字符串
        :param language: 语言
        :param location: 地区筛选
        :return:
        """
        # lat_lng = {"lat": "22.5745761", "lng": "113.9393772"}
        # 经纬度附近搜索
        # text_query_result = self.self._Google_Places.text_search(query='Gong Yuan', lat_lng=lat_lng)
        # location 为人可认识的名称
        # text_query_result = self.self._Google_Places.text_search(query='Tang Lang Shan', location='shenzhen')
        # 指定语言搜索
        text_query_result = self._Google_Places.text_search(query=query, language=language, location=location)
        return text_query_result.places

    def _reverse_geocode(self, lat, lng, language=None):
        """
        根据经纬度请求google API获取坐标信息,返回信息
        :param lat: 纬度
        :param lng:经度
        :param language:语言
        :return:
        """
        # 根据经纬度获取地址信息 pincode
        list_reverse_geocode_result = self._Google_Geocod.reverse_geocode((lat, lng), language=language)
        # print json.dumps(list_reverse_geocode_result, indent=4)
        return list_reverse_geocode_result

    def _return_reverse_geocode_info(self, lat, lng, language=None):
        """
        整理信息
        :param lat:纬度
        :param lng:经度
        :param language:语言
        :return:
        """
        list_reverse_geocode = self._reverse_geocode(lat, lng, language=language)
        if list_reverse_geocode:
            city = ''
            pincode = ''
            route = ''
            neighborhood = ''
            sublocality = ''
            administrative_area_level_1 = ''
            country = ''
            street_number = ''
            # 全名地址
            formatted_address = list_reverse_geocode[0]['formatted_address']
            for address_info in list_reverse_geocode[0]['address_components']:
                # 城市标识为locality
                if 'locality' in address_info['types']:
                    city = address_info['long_name']
                # 邮政编码标识为postal_code
                elif 'postal_code' in address_info['types']:
                    pincode = address_info['long_name']
                # 街道路
                elif 'route' in address_info['types']:
                    route = address_info['long_name']
                # 相似地址名
                elif 'neighborhood' in address_info['types']:
                    neighborhood = address_info['long_name']
                # 地区名
                elif 'sublocality' in address_info['types']:
                    sublocality = address_info['long_name']
                # 省份
                elif 'administrative_area_level_1' in address_info['types']:
                    administrative_area_level_1 = address_info['long_name']
                # 国家
                elif 'country' in address_info['types']:
                    country = address_info['long_name']
                # 门牌号
                elif 'street_number' in address_info['types']:
                    street_number = address_info['long_name']
            return {'city': city, 'pincode': pincode, 'route': route, 'neighborhood': neighborhood,
                    'sublocality': sublocality, 'administrative_area_level_1': administrative_area_level_1,
                    'country': country, 'formatted_address': formatted_address, 'street_number': street_number}
        else:
            return None

    def get_pincode_city(self, lat, lng, language=None):
        """
        根据经纬度获取该地区详细信息
        :param lat: 纬度
        :param lng: 经度
        :return:
        """
        reverse_geocode_info = self._return_reverse_geocode_info(lat, lng, language=language)
        if reverse_geocode_info:
            return {'city': reverse_geocode_info['city'], 'pincode': reverse_geocode_info['pincode']}
        else:
            return None

    def get_address_recommendation(self, query, language=None, location=None):
        """
        获取输入地址的推荐地址(最多返回5个)
        :param query: 搜索地址名称
        :param language: 语言
        :param location: 地区筛选
        :return:
        """
        return_size = 5
        list_return_info = list()
        list_places_text_search_result = self._text_search(query=query, language=language, location=location)
        # 默认返回5条数据
        if len(list_places_text_search_result) > return_size:
            list_places_text_search_result = list_places_text_search_result[:return_size]
        for place in list_places_text_search_result:
            result_geocode = self._return_reverse_geocode_info(place.geo_location['lat'], place.geo_location['lng'], language=language)
            # 数据不为空
            if result_geocode:
                # 地点全路径加上地点名
                result_geocode['formatted_address'] = '{} {}'.format(place.name, result_geocode['formatted_address'])
                result_geocode['place_name'] = place.name
                # 经纬度
                result_geocode['lat'] = '{}'.format(place.geo_location['lat'])
                result_geocode['lng'] = '{}'.format(place.geo_location['lng'])
                list_return_info.append(result_geocode)
        return list_return_info

# %%
import json

google_maps = GoogleMaps()
result_recommendation_list = google_maps.get_address_recommendation(query='天河公园', language='zh', location='中国')
pincode_city = google_maps.get_pincode_city(22.547143, 114.062753)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-77ddc2db1ffa> in <module>
#       2
#       3 google_maps = GoogleMaps()
# ----> 4 result_recommendation_list = google_maps.get_address_recommendation(query='天河公园', language='zh', location='中国')
#       5 pincode_city = google_maps.get_pincode_city(22.547143, 114.062753)
#
# <ipython-input-15-c9b252acd3a9> in get_address_recommendation(self, query, language, location)
#     112         return_size = 5
#     113         list_return_info = list()
# --> 114         list_places_text_search_result = self._text_search(query=query, language=language, location=location)
#     115         # 默认返回5条数据
#     116         if len(list_places_text_search_result) > return_size:
#
# <ipython-input-15-c9b252acd3a9> in _text_search(self, query, language, location)
#      22         # text_query_result = self.self._Google_Places.text_search(query='Tang Lang Shan', location='shenzhen')
#      23         # 指定语言搜索
# ---> 24         text_query_result = self._Google_Places.text_search(query=query, language=language, location=location)
#      25         return text_query_result.places
#      26
#
# F:\ProgramData\Anaconda3\lib\site-packages\googleplaces\__init__.py in text_search(self, query, language, lat_lng, radius, type, types, location, pagetoken)
#     334         self._request_params = {'query': query}
#     335         if lat_lng is not None or location is not None:
# --> 336             lat_lng_str = self._generate_lat_lng_string(lat_lng, location)
#     337             self._request_params['location'] = lat_lng_str
#     338         self._request_params['radius'] = radius
#
# F:\ProgramData\Anaconda3\lib\site-packages\googleplaces\__init__.py in _generate_lat_lng_string(self, lat_lng, location)
#     588         try:
#     589             return '%(lat)s,%(lng)s' % (lat_lng if lat_lng is not None
# --> 590                     else geocode_location(location=location, api_key=self.api_key))
#     591         except GooglePlacesError as e:
#     592             raise ValueError(
#
# F:\ProgramData\Anaconda3\lib\site-packages\googleplaces\__init__.py in geocode_location(location, sensor, api_key)
#     116         params['key'] = api_key
#     117     url, geo_response = _fetch_remote_json(
# --> 118             GooglePlaces.GEOCODE_API_URL, params)
#     119     _validate_response(url, geo_response)
#     120     if geo_response['status'] == GooglePlaces.RESPONSE_STATUS_ZERO_RESULTS:
#
# F:\ProgramData\Anaconda3\lib\site-packages\googleplaces\__init__.py in _fetch_remote_json(service_url, params, use_http_post)
#      78     request_url, response = _fetch_remote(service_url, params, use_http_post)
#      79     if six.PY3:
# ---> 80         str_response = response.read().decode('utf-8')
#      81         return (request_url, json.loads(str_response, parse_float=Decimal))
#      82     return (request_url, json.load(response, parse_float=Decimal))
#
# F:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     457
#     458             if self.length is None:
# --> 459                 s = self.fp.read()
#     460             else:
#     461                 try:
#
# F:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# F:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# F:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# F:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
google_maps = GoogleMaps()
pincode_city = google_maps.get_pincode_city(22.547143, 114.062753)
# Out:
# ---------------------------------------------------------------------------
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# <ipython-input-17-5f3b2f7d0268> in <module>
#       1 google_maps = GoogleMaps()
# ----> 2 pincode_city = google_maps.get_pincode_city(22.547143, 114.062753)
#
# <ipython-input-15-c9b252acd3a9> in get_pincode_city(self, lat, lng, language)
#      96         :return:
#      97         """
# ---> 98         reverse_geocode_info = self._return_reverse_geocode_info(lat, lng, language=language)
#      99         if reverse_geocode_info:
#     100             return {'city': reverse_geocode_info['city'], 'pincode': reverse_geocode_info['pincode']}
#
# <ipython-input-15-c9b252acd3a9> in _return_reverse_geocode_info(self, lat, lng, language)
#      46         :return:
#      47         """
# ---> 48         list_reverse_geocode = self._reverse_geocode(lat, lng, language=language)
#      49         if list_reverse_geocode:
#      50             city = ''
#
# <ipython-input-15-c9b252acd3a9> in _reverse_geocode(self, lat, lng, language)
#      34         """
#      35         # 根据经纬度获取地址信息 pincode
# ---> 36         list_reverse_geocode_result = self._Google_Geocod.reverse_geocode((lat, lng), language=language)
#      37         # print json.dumps(list_reverse_geocode_result, indent=4)
#      38         return list_reverse_geocode_result
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in wrapper(*args, **kwargs)
#     363     def wrapper(*args, **kwargs):
#     364         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 365         result = func(*args, **kwargs)
#     366         try:
#     367             del args[0]._extra_params
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\geocoding.py in reverse_geocode(client, latlng, result_type, location_type, language)
#     107         params["language"] = language
#     108
# --> 109     return client._request("/maps/api/geocode/json", params).get("results", [])
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# F:\ProgramData\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     208         elapsed = datetime.now() - first_request_time
#     209         if elapsed > self.retry_timeout:
# --> 210             raise googlemaps.exceptions.Timeout()
#     211
#     212         if retry_counter > 0:
#
# Timeout:

# %%
print json.dumps(result_recommendation_list, indent=4, encoding='utf-8')
print '*'*100
print pincode_city
